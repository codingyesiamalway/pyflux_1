# %%
import numpy as np
import pandas as pd
import pyflux as pf
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline 

data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/sunspot.year.csv')
data.index = data['time'].values


plt.figure(figsize=(15,5))
plt.plot(data.index,data['sunspot.year'])
plt.ylabel('Sunspots')
plt.title('Yearly Sunspot Data');

# %%
# for ar in range(1, 10):
#     for ma in range(1, 10):
#         model = pf.ARIMA(data=data,ar=ar,ma=ma,integ=0,target='sunspot.year')
#         x = model.fit("MLE")
#         print ar, ma, x.aic, x.bic
#         #model.plot_fit(figsize=(15,5))

# parameter selction. ar=3 and ma=8
model = pf.ARIMA(data=data,ar=4,ma=4,integ=0,target='sunspot.year')
x = model.fit("MLE")
print ar, ma, x.aic, x.bic
model.plot_fit(figsize=(15,5))
# Out:
# 9 9 2399.68495362 2436.20984543

# %%
# oos prediction going forward by 20 years

model.predict(h=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-ba660ac8234d> in <module>()
#       1 # oos prediction going forward by 20 years
#       2
# ----> 3 model.predict(h=20)
#
# /Users/yuzhao/anaconda/lib/python2.7/site-packages/pyflux/arma/arma.pyc in predict(self, h, intervals)
#     933
#     934             mu, Y = self._model(self.latent_variables.get_z_values())
# --> 935             date_index = self.shift_dates(h)
#     936
#     937             if self.latent_variables.estimation_method in ['M-H']:
#
# /Users/yuzhao/anaconda/lib/python2.7/site-packages/pyflux/tsm.pyc in shift_dates(self, h)
#     534         if self.is_pandas is True:
#     535
# --> 536             if isinstance(date_index, pd.core.indexes.datetimes.DatetimeIndex):
#     537
#     538                 if pd.infer_freq(date_index) in ['H', 'M', 'S']:
#
# ...
